# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Part I - WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# The first requirement is to create a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# After each plot, add a sentence or two explaining what the code is analyzing.
#
# The second requirement is to run linear regression on each relationship. This time, separate the plots into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude
#
# After each pair of plots, take the time to explain what the linear regression is modeling. For example, describe any relationships you notice and any other analysis you may have.
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1




print('Generating Data')
print('--------------------')
base_url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Generating Data
# --------------------
# Processing Record 1 of Set 1 : sao joao da barra
# Processing Record 2 of Set 1 : yar-sale
# Processing Record 3 of Set 1 : ostersund
# Processing Record 4 of Set 1 : georgetown
# Processing Record 5 of Set 1 : ushuaia
# Processing Record 6 of Set 1 : mackay
# Processing Record 7 of Set 1 : bluff
# Processing Record 8 of Set 1 : taseyevo
# Processing Record 9 of Set 1 : new norfolk
# Processing Record 10 of Set 1 : busselton
# Processing Record 11 of Set 1 : marzuq
# Processing Record 12 of Set 1 : bambous virieux
# Processing Record 13 of Set 1 : zhigansk
# City not found. Skipping...
# Processing Record 14 of Set 1 : mount isa
# Processing Record 15 of Set 1 : klaksvik
# Processing Record 16 of Set 1 : east london
# Processing Record 17 of Set 1 : souillac
# Processing Record 18 of Set 1 : kavieng
# Processing Record 19 of Set 1 : marquette
# Processing Record 20 of Set 1 : kapaa
# Processing Record 21 of Set 1 : rikitea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 1 : cochrane
# Processing Record 23 of Set 1 : albany
# Processing Record 24 of Set 1 : lethem
# Processing Record 25 of Set 1 : castro
# Processing Record 26 of Set 1 : port elizabeth
# Processing Record 27 of Set 1 : hilo
# Processing Record 28 of Set 1 : saskylakh
# Processing Record 29 of Set 1 : tonantins
# Processing Record 30 of Set 1 : pisco
# Processing Record 31 of Set 1 : tekanpur
# Processing Record 32 of Set 1 : sheridan
# Processing Record 33 of Set 1 : carnarvon
# Processing Record 34 of Set 1 : dikson
# City not found. Skipping...
# Processing Record 35 of Set 1 : shingu
# Processing Record 36 of Set 1 : kailua
# Processing Record 37 of Set 1 : mar del plata
# Processing Record 38 of Set 1 : teya
# Processing Record 39 of Set 1 : bandarbeyla
# Processing Record 40 of Set 1 : ruteng
# Processing Record 41 of Set 1 : cabras
# Processing Record 42 of Set 1 : katsuura
# Processing Record 43 of Set 1 : avarua
# Processing Record 44 of Set 1 : puerto ayora
# Processing Record 45 of Set 1 : atuona
# City not found. Skipping...
# Processing Record 46 of Set 1 : thessalon
# Processing Record 47 of Set 1 : esperance
# Processing Record 48 of Set 1 : lubango
# City not found. Skipping...
# Processing Record 49 of Set 1 : panaba
# Processing Record 50 of Set 1 : jamestown
# Processing Record 0 of Set 2 : lagoa
# Processing Record 1 of Set 2 : suntar
# Processing Record 2 of Set 2 : kodiak
# Processing Record 3 of Set 2 : hami
# Processing Record 4 of Set 2 : hobart
# Processing Record 5 of Set 2 : narsaq
# City not found. Skipping...
# Processing Record 6 of Set 2 : harper
# Processing Record 7 of Set 2 : qaanaaq
# Processing Record 8 of Set 2 : salalah
# Processing Record 9 of Set 2 : ribeira grande
# Processing Record 10 of Set 2 : sao filipe
# Processing Record 11 of Set 2 : gimli
# Processing Record 12 of Set 2 : killybegs
# Processing Record 13 of Set 2 : nikolskoye
# Processing Record 14 of Set 2 : geraldton
# Processing Record 15 of Set 2 : mataura
# Processing Record 16 of Set 2 : barabinsk
# City not found. Skipping...
# Processing Record 17 of Set 2 : myrtle beach
# Processing Record 18 of Set 2 : hermanus
# Processing Record 19 of Set 2 : padang
# Processing Record 20 of Set 2 : khatanga
# Processing Record 21 of Set 2 : mildura
# Processing Record 22 of Set 2 : bereda
# Processing Record 23 of Set 2 : bahia blanca
# Processing Record 24 of Set 2 : cabo san lucas
# Processing Record 25 of Set 2 : wanganui
# City not found. Skipping...
# Processing Record 26 of Set 2 : saint-philippe
# Processing Record 27 of Set 2 : nacimiento
# Processing Record 28 of Set 2 : boa vista
# Processing Record 29 of Set 2 : mmabatho
# Processing Record 30 of Set 2 : roma
# Processing Record 31 of Set 2 : sistranda
# Processing Record 32 of Set 2 : sheltozero
# Processing Record 33 of Set 2 : thompson
# Processing Record 34 of Set 2 : chokurdakh
# Processing Record 35 of Set 2 : ouesso
# Processing Record 36 of Set 2 : punta arenas
# Processing Record 37 of Set 2 : provideniya
# Processing Record 38 of Set 2 : cape town
# Processing Record 39 of Set 2 : marienburg
# Processing Record 40 of Set 2 : quatre cocos
# Processing Record 41 of Set 2 : torbay
# Processing Record 42 of Set 2 : ketchikan
# Processing Record 43 of Set 2 : lebu
# Processing Record 44 of Set 2 : fort nelson
# City not found. Skipping...
# Processing Record 45 of Set 2 : severo-kurilsk
# Processing Record 46 of Set 2 : port lincoln
# Processing Record 47 of Set 2 : yumen
# City not found. Skipping...
# Processing Record 48 of Set 2 : olafsvik
# City not found. Skipping...
# Processing Record 49 of Set 2 : awbari
# Processing Record 50 of Set 2 : tanout
# Processing Record 0 of Set 3 : tiksi
# Processing Record 1 of Set 3 : tepla
# Processing Record 2 of Set 3 : de-kastri
# Processing Record 3 of Set 3 : naze
# Processing Record 4 of Set 3 : yellowknife
# Processing Record 5 of Set 3 : saint-augustin
# Processing Record 6 of Set 3 : sitka
# Processing Record 7 of Set 3 : catemaco
# Processing Record 8 of Set 3 : peski
# Processing Record 9 of Set 3 : cockburn town
# Processing Record 10 of Set 3 : tasiilaq
# Processing Record 11 of Set 3 : sibu
# Processing Record 12 of Set 3 : lanxi
# Processing Record 13 of Set 3 : butaritari
# Processing Record 14 of Set 3 : nanakuli
# Processing Record 15 of Set 3 : paita
# Processing Record 16 of Set 3 : dudinka
# Processing Record 17 of Set 3 : kiunga
# Processing Record 18 of Set 3 : ahuimanu
# Processing Record 19 of Set 3 : port alfred
# Processing Record 20 of Set 3 : seguela
# Processing Record 21 of Set 3 : dongying
# Processing Record 22 of Set 3 : dunedin
# Processing Record 23 of Set 3 : leningradskiy
# Processing Record 24 of Set 3 : isiro
# Processing Record 25 of Set 3 : fairbanks
# Processing Record 26 of Set 3 : kalmar
# Processing Record 27 of Set 3 : olovyannaya
# Processing Record 28 of Set 3 : dingle
# Processing Record 29 of Set 3 : norman wells
# Processing Record 30 of Set 3 : haines junction
# City not found. Skipping...
# Processing Record 31 of Set 3 : tuktoyaktuk
# Processing Record 32 of Set 3 : itoman
# Processing Record 33 of Set 3 : santa cruz
# Processing Record 34 of Set 3 : lufilufi
# Processing Record 35 of Set 3 : manakara
# City not found. Skipping...
# Processing Record 36 of Set 3 : lasa
# Processing Record 37 of Set 3 : khandyga
# Processing Record 38 of Set 3 : arraial do cabo
# Processing Record 39 of Set 3 : airai
# Processing Record 40 of Set 3 : ca mau
# Processing Record 41 of Set 3 : opuwo
# Processing Record 42 of Set 3 : pithoro
# Processing Record 43 of Set 3 : ballangen
# Processing Record 44 of Set 3 : vaini
# Processing Record 45 of Set 3 : cayenne
# Processing Record 46 of Set 3 : valparaiso
# Processing Record 47 of Set 3 : vawkavysk
# Processing Record 48 of Set 3 : rochelle
# Processing Record 49 of Set 3 : santa maria
# Processing Record 50 of Set 3 : vila velha
# Processing Record 0 of Set 4 : hailun
# Processing Record 1 of Set 4 : ridgecrest
# Processing Record 2 of Set 4 : barrow
# Processing Record 3 of Set 4 : ponta do sol
# Processing Record 4 of Set 4 : cabedelo
# Processing Record 5 of Set 4 : berlevag
# Processing Record 6 of Set 4 : kenai
# Processing Record 7 of Set 4 : dodge city
# Processing Record 8 of Set 4 : college
# Processing Record 9 of Set 4 : bredasdorp
# Processing Record 10 of Set 4 : bathsheba
# Processing Record 11 of Set 4 : montlucon
# Processing Record 12 of Set 4 : iracoubo
# Processing Record 13 of Set 4 : yemelyanovo
# Processing Record 14 of Set 4 : vuktyl
# Processing Record 15 of Set 4 : isangel
# Processing Record 16 of Set 4 : vila franca do campo
# Processing Record 17 of Set 4 : ancud
# Processing Record 18 of Set 4 : obo
# Processing Record 19 of Set 4 : honghu
# Processing Record 20 of Set 4 : acapulco
# Processing Record 21 of Set 4 : guder
# City not found. Skipping...
# Processing Record 22 of Set 4 : biograd na moru
# Processing Record 23 of Set 4 : grand gaube
# Processing Record 24 of Set 4 : saldanha
# Processing Record 25 of Set 4 : san patricio
# Processing Record 26 of Set 4 : simplicio mendes
# City not found. Skipping...
# Processing Record 27 of Set 4 : petropavlovsk-kamchatskiy
# Processing Record 28 of Set 4 : paamiut
# City not found. Skipping...
# Processing Record 29 of Set 4 : samarai
# Processing Record 30 of Set 4 : hervey bay
# Processing Record 31 of Set 4 : nouadhibou
# Processing Record 32 of Set 4 : nador
# Processing Record 33 of Set 4 : ilulissat
# Processing Record 34 of Set 4 : niksic
# Processing Record 35 of Set 4 : george
# Processing Record 36 of Set 4 : itacare
# Processing Record 37 of Set 4 : agua branca
# Processing Record 38 of Set 4 : guarapari
# Processing Record 39 of Set 4 : saint-francois
# Processing Record 40 of Set 4 : lavrentiya
# Processing Record 41 of Set 4 : ust-maya
# Processing Record 42 of Set 4 : oriximina
# Processing Record 43 of Set 4 : saint george
# Processing Record 44 of Set 4 : calahorra
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 4 : goya
# Processing Record 46 of Set 4 : salinas
# Processing Record 47 of Set 4 : ust-nera
# Processing Record 48 of Set 4 : coahuayana
# Processing Record 49 of Set 4 : riyadh
# Processing Record 50 of Set 4 : mahebourg
# Processing Record 0 of Set 5 : scarborough
# Processing Record 1 of Set 5 : kaitangata
# Processing Record 2 of Set 5 : adwa
# City not found. Skipping...
# Processing Record 3 of Set 5 : joao pinheiro
# Processing Record 4 of Set 5 : kasempa
# Processing Record 5 of Set 5 : lamu
# Processing Record 6 of Set 5 : kruisfontein
# Processing Record 7 of Set 5 : pevek
# Processing Record 8 of Set 5 : te anau
# Processing Record 9 of Set 5 : gambiran
# Processing Record 10 of Set 5 : darnah
# Processing Record 11 of Set 5 : ribas do rio pardo
# Processing Record 12 of Set 5 : nanortalik
# Processing Record 13 of Set 5 : maloyaroslavets
# Processing Record 14 of Set 5 : longhua
# Processing Record 15 of Set 5 : cherskiy
# Processing Record 16 of Set 5 : zaraza
# Processing Record 17 of Set 5 : asau
# Processing Record 18 of Set 5 : xam nua
# Processing Record 19 of Set 5 : severnoye
# Processing Record 20 of Set 5 : kununurra
# City not found. Skipping...
# Processing Record 21 of Set 5 : fuling
# Processing Record 22 of Set 5 : chapais
# Processing Record 23 of Set 5 : pahrump
# Processing Record 24 of Set 5 : shache
# Processing Record 25 of Set 5 : karlskrona
# Processing Record 26 of Set 5 : bethel
# Processing Record 27 of Set 5 : yayva
# Processing Record 28 of Set 5 : maun
# Processing Record 29 of Set 5 : hithadhoo
# Processing Record 30 of Set 5 : kieta
# Processing Record 31 of Set 5 : zhezkazgan
# Processing Record 32 of Set 5 : dawson creek
# Processing Record 33 of Set 5 : trinidad
# Processing Record 34 of Set 5 : tuatapere
# Processing Record 35 of Set 5 : omboue
# Processing Record 36 of Set 5 : verkhneyarkeyevo
# Processing Record 37 of Set 5 : conway
# Processing Record 38 of Set 5 : pemangkat
# Processing Record 39 of Set 5 : ivdel
# Processing Record 40 of Set 5 : hasaki
# Processing Record 41 of Set 5 : saint-ambroise
# Processing Record 42 of Set 5 : sapa
# Processing Record 43 of Set 5 : kirakira
# Processing Record 44 of Set 5 : cidreira
# Processing Record 45 of Set 5 : vrangel
# Processing Record 46 of Set 5 : shuangcheng
# Processing Record 47 of Set 5 : nema
# Processing Record 48 of Set 5 : matay
# Processing Record 49 of Set 5 : moose factory
# Processing Record 50 of Set 5 : azle
# City not found. Skipping...
# Processing Record 0 of Set 6 : tambun
# Processing Record 1 of Set 6 : talnakh
# Processing Record 2 of Set 6 : fortuna
# Processing Record 3 of Set 6 : san quintin
# Processing Record 4 of Set 6 : estelle
# City not found. Skipping...
# Processing Record 5 of Set 6 : nara
# Processing Record 6 of Set 6 : muros
# Processing Record 7 of Set 6 : kitimat
# Processing Record 8 of Set 6 : pundaguitan
# City not found. Skipping...
# Processing Record 9 of Set 6 : kimbe
# Processing Record 10 of Set 6 : maxixe
# Processing Record 11 of Set 6 : brae
# Processing Record 12 of Set 6 : bilma
# Processing Record 13 of Set 6 : longyearbyen
# Processing Record 14 of Set 6 : northam
# Processing Record 15 of Set 6 : wiarton
# Processing Record 16 of Set 6 : tura
# Processing Record 17 of Set 6 : tessalit
# Processing Record 18 of Set 6 : nikki
# Processing Record 19 of Set 6 : chuy
# Processing Record 20 of Set 6 : boralday
# Processing Record 21 of Set 6 : port-cartier
# Processing Record 22 of Set 6 : beloha
# Processing Record 23 of Set 6 : victoria
# Processing Record 24 of Set 6 : upernavik
# Processing Record 25 of Set 6 : ferrenafe
# Processing Record 26 of Set 6 : klofta
# Processing Record 27 of Set 6 : port hardy
# Processing Record 28 of Set 6 : puerto varas
# Processing Record 29 of Set 6 : vanimo
# Processing Record 30 of Set 6 : nisia floresta
# Processing Record 31 of Set 6 : baie-comeau
# Processing Record 32 of Set 6 : gat
# Processing Record 33 of Set 6 : ajdabiya
# Processing Record 34 of Set 6 : ixtapa
# Processing Record 35 of Set 6 : guia de isora
# Processing Record 36 of Set 6 : tezu
# Processing Record 37 of Set 6 : smithers
# Processing Record 38 of Set 6 : bengkulu
# Processing Record 39 of Set 6 : cabra
# Processing Record 40 of Set 6 : saint-pierre
# City not found. Skipping...
# Processing Record 41 of Set 6 : sinnar
# Processing Record 42 of Set 6 : axim
# Processing Record 43 of Set 6 : palmerston
# Processing Record 44 of Set 6 : yulara
# Processing Record 45 of Set 6 : guerrero negro
# Processing Record 46 of Set 6 : san antonio
# Processing Record 47 of Set 6 : buchanan
# Processing Record 48 of Set 6 : adrar
# Processing Record 49 of Set 6 : kijang
# Processing Record 50 of Set 6 : rio cuarto
# Processing Record 0 of Set 7 : sena madureira
# Processing Record 1 of Set 7 : belmonte
# Processing Record 2 of Set 7 : thinadhoo
# Processing Record 3 of Set 7 : necochea
# Processing Record 4 of Set 7 : nelipyno
# Processing Record 5 of Set 7 : iqaluit
# Processing Record 6 of Set 7 : batemans bay
# Processing Record 7 of Set 7 : kaiyuan
# Processing Record 8 of Set 7 : deputatskiy
# Processing Record 9 of Set 7 : dembi dolo
# Processing Record 10 of Set 7 : touros
# Processing Record 11 of Set 7 : yanam
# Processing Record 12 of Set 7 : svetlogorsk
# Processing Record 13 of Set 7 : sabang
# Processing Record 14 of Set 7 : paipa
# Processing Record 15 of Set 7 : turukhansk
# Processing Record 16 of Set 7 : pangkalanbuun
# Processing Record 17 of Set 7 : santa cruz de tenerife
# Processing Record 18 of Set 7 : choix
# Processing Record 19 of Set 7 : delaware
# Processing Record 20 of Set 7 : akureyri
# Processing Record 21 of Set 7 : vlore
# Processing Record 22 of Set 7 : bethanien
# Processing Record 23 of Set 7 : galveston
# Processing Record 24 of Set 7 : asosa
# Processing Record 25 of Set 7 : porto novo
# City not found. Skipping...
# Processing Record 26 of Set 7 : flinders
# Processing Record 27 of Set 7 : marathon
# Processing Record 28 of Set 7 : vardo
# Processing Record 29 of Set 7 : bambanglipuro
# City not found. Skipping...
# Processing Record 30 of Set 7 : lorengau
# Processing Record 31 of Set 7 : faanui
# Processing Record 32 of Set 7 : nishihara
# Processing Record 33 of Set 7 : yuncheng
# Processing Record 34 of Set 7 : pires do rio
# Processing Record 35 of Set 7 : alta floresta
# Processing Record 36 of Set 7 : anadyr
# Processing Record 37 of Set 7 : mount darwin
# Processing Record 38 of Set 7 : hoquiam
# City not found. Skipping...
# Processing Record 39 of Set 7 : darhan
# Processing Record 40 of Set 7 : nangomba
# City not found. Skipping...
# Processing Record 41 of Set 7 : vestmannaeyjar
# Processing Record 42 of Set 7 : porto santo
# City not found. Skipping...
# Processing Record 43 of Set 7 : montes claros
# Processing Record 44 of Set 7 : tuy hoa
# Processing Record 45 of Set 7 : tarakan
# Processing Record 46 of Set 7 : shirokiy
# Processing Record 47 of Set 7 : jinchang
# Processing Record 48 of Set 7 : chlorakas
# Processing Record 49 of Set 7 : mastic beach
# Processing Record 50 of Set 7 : olinda
# Processing Record 0 of Set 8 : aklavik
# Processing Record 1 of Set 8 : torphins
# Processing Record 2 of Set 8 : svetlyy
# Processing Record 3 of Set 8 : pangoa
# City not found. Skipping...
# Processing Record 4 of Set 8 : fernie
# Processing Record 5 of Set 8 : aksarka
# Processing Record 6 of Set 8 : zhaotong
# Processing Record 7 of Set 8 : ulagan
# Processing Record 8 of Set 8 : aquitania
# Processing Record 9 of Set 8 : luderitz
# Processing Record 10 of Set 8 : chara
# Processing Record 11 of Set 8 : kastamonu
# Processing Record 12 of Set 8 : alto longa
# Processing Record 13 of Set 8 : saint anthony
# Processing Record 14 of Set 8 : komsomolskiy
# Processing Record 15 of Set 8 : coihaique
# Processing Record 16 of Set 8 : bud
# Processing Record 17 of Set 8 : clarksburg
# Processing Record 18 of Set 8 : mana
# Processing Record 19 of Set 8 : nalut
# Processing Record 20 of Set 8 : tucuman
# Processing Record 21 of Set 8 : aswan
# Processing Record 22 of Set 8 : ganderkesee
# Processing Record 23 of Set 8 : upington
# Processing Record 24 of Set 8 : tooele
# Processing Record 25 of Set 8 : labuhan
# Processing Record 26 of Set 8 : wasilla
# City not found. Skipping...
# Processing Record 27 of Set 8 : palmer
# Processing Record 28 of Set 8 : san cristobal
# Processing Record 29 of Set 8 : hudiksvall
# Processing Record 30 of Set 8 : prince george
# Processing Record 31 of Set 8 : hiranagar
# Processing Record 32 of Set 8 : two rivers
# Processing Record 33 of Set 8 : batticaloa
# Processing Record 34 of Set 8 : boo
# Processing Record 35 of Set 8 : edgewater
# Processing Record 36 of Set 8 : kashi
# Processing Record 37 of Set 8 : khorramshahr
# Processing Record 38 of Set 8 : cangucu
# Processing Record 39 of Set 8 : carauari
# Processing Record 40 of Set 8 : sinnamary
# Processing Record 41 of Set 8 : cabo rojo
# Processing Record 42 of Set 8 : aktash
# Processing Record 43 of Set 8 : bay saint louis
# Processing Record 44 of Set 8 : lakatoro
# Processing Record 45 of Set 8 : sulangan
# Processing Record 46 of Set 8 : utraula
# Processing Record 47 of Set 8 : calvia
# Processing Record 48 of Set 8 : tual
# Processing Record 49 of Set 8 : ukiah
# Processing Record 50 of Set 8 : sabzevar
# Processing Record 0 of Set 9 : tabuk
# Processing Record 1 of Set 9 : cancun
# Processing Record 2 of Set 9 : huarmey
# City not found. Skipping...
# Processing Record 3 of Set 9 : constitucion
# City not found. Skipping...
# Processing Record 4 of Set 9 : denpasar
# Processing Record 5 of Set 9 : abay
# Processing Record 6 of Set 9 : asyut
# Processing Record 7 of Set 9 : edea
# Processing Record 8 of Set 9 : anloga
# Processing Record 9 of Set 9 : tagusao
# Processing Record 10 of Set 9 : aparecida do taboado
# Processing Record 11 of Set 9 : vestmanna
# Processing Record 12 of Set 9 : rio gallegos
# Processing Record 13 of Set 9 : birin
# Processing Record 14 of Set 9 : tymovskoye
# Processing Record 15 of Set 9 : roxana
# Processing Record 16 of Set 9 : ler
# Processing Record 17 of Set 9 : carberry
# Processing Record 18 of Set 9 : raahe
# Processing Record 19 of Set 9 : los llanos de aridane
# Processing Record 20 of Set 9 : kyren
# Processing Record 21 of Set 9 : pangnirtung
# Processing Record 22 of Set 9 : tautira
# Processing Record 23 of Set 9 : camrose
# Processing Record 24 of Set 9 : egvekinot
# Processing Record 25 of Set 9 : codrington
# Processing Record 26 of Set 9 : plettenberg bay
# Processing Record 27 of Set 9 : kingman
# Processing Record 28 of Set 9 : chaumont
# Processing Record 29 of Set 9 : nizhnyaya tavda
# Processing Record 30 of Set 9 : bani
# Processing Record 31 of Set 9 : dawei
# Processing Record 32 of Set 9 : unhel
# City not found. Skipping...
# Processing Record 33 of Set 9 : buala
# Processing Record 34 of Set 9 : shimoda
# Processing Record 35 of Set 9 : comodoro rivadavia
# Processing Record 36 of Set 9 : soyo
# City not found. Skipping...
# Processing Record 37 of Set 9 : isla mujeres
# Processing Record 38 of Set 9 : tambura
# Processing Record 39 of Set 9 : la rioja
# Processing Record 40 of Set 9 : arcachon
# Processing Record 41 of Set 9 : port hedland
# Processing Record 42 of Set 9 : catuday
# Processing Record 43 of Set 9 : russell
# Processing Record 44 of Set 9 : coquimbo
# Processing Record 45 of Set 9 : ventspils
# City not found. Skipping...
# Processing Record 46 of Set 9 : general roca
# Processing Record 47 of Set 9 : hambantota
# Processing Record 48 of Set 9 : yokadouma
# Processing Record 49 of Set 9 : mareeba
# Processing Record 50 of Set 9 : dehloran
# Processing Record 0 of Set 10 : cairns
# Processing Record 1 of Set 10 : neiafu
# Processing Record 2 of Set 10 : pangai
# Processing Record 3 of Set 10 : sisimiut
# Processing Record 4 of Set 10 : bongandanga
# City not found. Skipping...
# Processing Record 5 of Set 10 : mount gambier
# Processing Record 6 of Set 10 : kuytun
# Processing Record 7 of Set 10 : arnedo
# Processing Record 8 of Set 10 : srednekolymsk
# Processing Record 9 of Set 10 : matara
# Processing Record 10 of Set 10 : vostok
# Processing Record 11 of Set 10 : taoudenni
# Processing Record 12 of Set 10 : kota bahru
# Processing Record 13 of Set 10 : camacha
# Processing Record 14 of Set 10 : dodoma
# Processing Record 15 of Set 10 : luganville
# Processing Record 16 of Set 10 : torrijos
# Processing Record 17 of Set 10 : ryotsu
# Processing Record 18 of Set 10 : solnechnyy
# Processing Record 19 of Set 10 : alofi
# City not found. Skipping...
# Processing Record 20 of Set 10 : greenwood
# Processing Record 21 of Set 10 : gobabis
# Processing Record 22 of Set 10 : sindor
# Processing Record 23 of Set 10 : hamilton
# Processing Record 24 of Set 10 : catamarca
# Processing Record 25 of Set 10 : koboko
# Processing Record 26 of Set 10 : arroyo
# Processing Record 27 of Set 10 : hofn
# Processing Record 28 of Set 10 : media luna
# Processing Record 29 of Set 10 : neustrelitz
# Processing Record 30 of Set 10 : taoyuan
# Processing Record 31 of Set 10 : weiser
# City not found. Skipping...
# Processing Record 32 of Set 10 : casablanca
# Processing Record 33 of Set 10 : marawi
# City not found. Skipping...
# Processing Record 34 of Set 10 : benguela
# Processing Record 35 of Set 10 : kanniyakumari
# Processing Record 36 of Set 10 : poum
# Processing Record 37 of Set 10 : gunjur
# Processing Record 38 of Set 10 : khrebtovaya
# Processing Record 39 of Set 10 : hare bay
# Processing Record 40 of Set 10 : sunrise manor
# Processing Record 41 of Set 10 : skjervoy
# Processing Record 42 of Set 10 : guaymas
# Processing Record 43 of Set 10 : mamlyutka
# Processing Record 44 of Set 10 : lompoc
# Processing Record 45 of Set 10 : san carlos de bariloche
# Processing Record 46 of Set 10 : san julian
# City not found. Skipping...
# Processing Record 47 of Set 10 : southbridge
# Processing Record 48 of Set 10 : portland
# Processing Record 49 of Set 10 : anaco
# Processing Record 50 of Set 10 : sola
# Processing Record 0 of Set 11 : margate
# Processing Record 1 of Set 11 : itarema
# Processing Record 2 of Set 11 : urengoy
# Processing Record 3 of Set 11 : maniitsoq
# Processing Record 4 of Set 11 : muisne
# Processing Record 5 of Set 11 : kalmunai
# Processing Record 6 of Set 11 : ilebo
# Processing Record 7 of Set 11 : west bay
# Processing Record 8 of Set 11 : inuvik
# Processing Record 9 of Set 11 : la ronge
# Processing Record 10 of Set 11 : lata
# Processing Record 11 of Set 11 : sovetskiy
# Processing Record 12 of Set 11 : port blair
# Processing Record 13 of Set 11 : kindu
# Processing Record 14 of Set 11 : silver city
# Processing Record 15 of Set 11 : alexandroupoli
# Processing Record 16 of Set 11 : batagay-alyta
# Processing Record 17 of Set 11 : lima
# Processing Record 18 of Set 11 : grindavik
# Processing Record 19 of Set 11 : verkhoshizhemye
# Processing Record 20 of Set 11 : erenhot
# Processing Record 21 of Set 11 : manacapuru
# Processing Record 22 of Set 11 : okhotsk
# Processing Record 23 of Set 11 : kourou
# Processing Record 24 of Set 11 : xinqing
# Processing Record 25 of Set 11 : roald
# Processing Record 26 of Set 11 : mogzon
# City not found. Skipping...
# Processing Record 27 of Set 11 : abha
# Processing Record 28 of Set 11 : buta
# Processing Record 29 of Set 11 : kampot
# Processing Record 30 of Set 11 : north battleford
# Processing Record 31 of Set 11 : manggar
# Processing Record 32 of Set 11 : kavaratti
# Processing Record 33 of Set 11 : irgakly
# Processing Record 34 of Set 11 : longonjo
# Processing Record 35 of Set 11 : heihe
# Processing Record 36 of Set 11 : namatanai
# Processing Record 37 of Set 11 : bafia
# Processing Record 38 of Set 11 : penalva
# Processing Record 39 of Set 11 : nizhyn
# Processing Record 40 of Set 11 : latung
# Processing Record 41 of Set 11 : petropavl
# Processing Record 42 of Set 11 : verkhnevilyuysk
# Processing Record 43 of Set 11 : zacapoaxtla
# Processing Record 44 of Set 11 : caravelas
# Processing Record 45 of Set 11 : srandakan
# Processing Record 46 of Set 11 : pineville
# Processing Record 47 of Set 11 : avera
# Processing Record 48 of Set 11 : berestechko
# Processing Record 49 of Set 11 : kadaura
# Processing Record 50 of Set 11 : novita
# Processing Record 0 of Set 12 : singapore
# Processing Record 1 of Set 12 : tukrah
# Processing Record 2 of Set 12 : pouembout
# Processing Record 3 of Set 12 : kodinsk
# City not found. Skipping...
# Processing Record 4 of Set 12 : banjar
# Processing Record 5 of Set 12 : ankara
# Processing Record 6 of Set 12 : nizhnevartovsk
# Processing Record 7 of Set 12 : bergama
# Processing Record 8 of Set 12 : gushikawa
# Processing Record 9 of Set 12 : kokstad
# Processing Record 10 of Set 12 : tala
# Processing Record 11 of Set 12 : laela
# Processing Record 12 of Set 12 : tilichiki
# Processing Record 13 of Set 12 : sambava
# City not found. Skipping...
# Processing Record 14 of Set 12 : mitsamiouli
# Processing Record 15 of Set 12 : khani
# Processing Record 16 of Set 12 : sarangani
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# data frame for analysis
weather_data = pd.DataFrame({"City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list})

weather_data.count()
# Out:
# City          577
# Cloudiness    577
# Country       577
# Date          577
# Humidity      577
# Lat           577
# Lng           577
# Max Temp      577
# Wind Speed    577
# dtype: int64

# %%
# data check
weather_data
# Out:
#                   City  Cloudiness Country        Date  Humidity      Lat  \
# 0    São João da Barra           0      BR  1619270609        57 -21.6403
# 1             Yar-Sale          99      RU  1619270609        93  66.8333
# 2            Östersund          40      SE  1619270610        41  63.1792
# 3          George Town          20      MY  1619270481        74   5.4112
# 4              Ushuaia          75      AR  1619270312        81 -54.8000
# ..                 ...         ...     ...         ...       ...      ...
# 572          Tilichiki          98      RU  1619270785        94  60.4667
# 573            Sambava          13      MG  1619270785        77 -14.2667
# 574        Mitsamiouli          75      KM  1619270785        83 -11.3847
# 575              Khani           0      GE  1619270786        49  41.9563
# 576          Sarangani           4      PH  1619270593        77   5.4033
#
#           Lng  Max Temp  Wind Speed
# 0    -41.0511     80.60        4.61
# 1     70.8333     33.75        5.82
# 2     14.6357     36.00       18.41
# 3    100.3354     84.20        2.30
# 4    -68.3000     44.60        5.75
# ..        ...       ...         ...
# 572  166.1000     20.19        4.43
# 573   50.1667     80.94       13.89
# 574   43.2844     80.60       13.80
# 575   42.9566     68.00       16.11
# 576  125.4636     83.86       15.46
#
# [577 rows x 9 columns]

# %%
# convert to csv file for analysis
weather_data.to_csv("weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_data.sort_values(by=['Humidity'], ascending=False)

# NO CITIES THAT HAVE HUMIDITY > 100%
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 454     Hambantota          40      LK  1619270749       100   6.1241
# 240         Conway          90      US  1619270439       100  35.0887
# 281     Port Hardy          90      CA  1619270400       100  50.6996
# 340  Alta Floresta          40      BR  1619270714       100  -9.8756
# 89         Malbork          97      PL  1619270636       100  54.0359
# ..             ...         ...     ...         ...       ...      ...
# 558        Kadaura         100      IN  1619270781         6  25.9833
# 266          Bilma           7      NE  1619270691         5  18.6853
# 457       Dehlorān          18      IR  1619270750         5  32.6941
# 30        Tekanpur          96      IN  1619270618         5  25.9833
# 271       Tessalit           0      ML  1619270692         4  20.1986
#
#           Lng  Max Temp  Wind Speed
# 454   81.1185     82.40        3.44
# 240  -92.4421     57.20        4.61
# 281 -127.4199     44.60        2.46
# 340  -56.0861     77.00        5.75
# 89    19.0266     52.00       14.67
# ..        ...       ...         ...
# 558   79.8500     97.11       13.11
# 266   12.9164    106.99       11.05
# 457   47.2679    101.30       16.62
# 30    78.2667     91.99        8.34
# 271    1.0114    102.49        7.96
#
# [577 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], facecolor = "orange", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (24Apr21)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

print("This chart clearly demonstrates that the closer to the equator, the higher the temperature, and the temperature decreases    more as we move farther away in the northern hemisphere")
# Out:
# This chart clearly demonstrates that the closer to the equator, the higher the temperature, and the temperature decreases    more as we move farther away in the northern hemisphere

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Humidity Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Humidity"], facecolor = "blue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (24Apr21)")

# Set x axis label
plt.xlabel("Latitude")

# Set y axis label
plt.ylabel("Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

print("Looking at this graph, there seems to be no true correlation between humidity and latitude.")
# Out:
# Looking at this graph, there seems to be no true correlation between humidity and latitude.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], facecolor = "grey", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (24Apr21)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Cloudiness (%)")

# Set y axis limit
plt.ylim(-5,105)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

print("There is no direct correlation between cloudiness and location. Cloudiness seems to vary greatly across latitudes.")
# Out:
# There is no direct correlation between cloudiness and location. Cloudiness seems to vary greatly across latitudes.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed scatter plot
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], facecolor = "yellow", edgecolor = "black")
plt.title("City Latitude vs. Wind Speed (mph) (24Apr21)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Wind Speed (%)")

# Set y axis limit
plt.ylim(-2,50)

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

print("Windspeed does not vary greatly across latitude. There is no direct correlation.")
# Out:
# Windspeed does not vary greatly across latitude. There is no direct correlation.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

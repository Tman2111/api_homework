# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# ## Part I - WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# The first requirement is to create a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# After each plot, add a sentence or two explaining what the code is analyzing.
#
# The second requirement is to run linear regression on each relationship. This time, separate the plots into Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude):
#
# * Northern Hemisphere - Temperature (F) vs. Latitude
# * Southern Hemisphere - Temperature (F) vs. Latitude
# * Northern Hemisphere - Humidity (%) vs. Latitude
# * Southern Hemisphere - Humidity (%) vs. Latitude
# * Northern Hemisphere - Cloudiness (%) vs. Latitude
# * Southern Hemisphere - Cloudiness (%) vs. Latitude
# * Northern Hemisphere - Wind Speed (mph) vs. Latitude
# * Southern Hemisphere - Wind Speed (mph) vs. Latitude
#
# After each pair of plots, take the time to explain what the linear regression is modeling. For example, describe any relationships you notice and any other analysis you may have.
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * Include a print log of each city as it's being processed with the city number and city name.
# * Save a CSV of all retrieved data and a PNG image for each scatter plot.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 577

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1




print('Generating Data')
print('--------------------')
base_url = "http://api.openweathermap.org/data/2.5/weather?"

units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Generating Data
# --------------------
# Processing Record 1 of Set 1 : atuona
# Processing Record 2 of Set 1 : rikitea
# City not found. Skipping...
# Processing Record 3 of Set 1 : union
# Processing Record 4 of Set 1 : barvinkove
# Processing Record 5 of Set 1 : hithadhoo
# Processing Record 6 of Set 1 : mogadishu
# Processing Record 7 of Set 1 : port macquarie
# Processing Record 8 of Set 1 : bandarbeyla
# Processing Record 9 of Set 1 : dawlatabad
# Processing Record 10 of Set 1 : hilo
# Processing Record 11 of Set 1 : hobart
# Processing Record 12 of Set 1 : port alfred
# Processing Record 13 of Set 1 : saskylakh
# Processing Record 14 of Set 1 : ust-kuyga
# Processing Record 15 of Set 1 : qaanaaq
# Processing Record 16 of Set 1 : klaksvik
# Processing Record 17 of Set 1 : severo-kurilsk
# Processing Record 18 of Set 1 : faanui
# Processing Record 19 of Set 1 : hofn
# Processing Record 20 of Set 1 : vaini
# Processing Record 21 of Set 1 : albany
# Processing Record 22 of Set 1 : avarua
# Processing Record 23 of Set 1 : itarsi
# Processing Record 24 of Set 1 : dikson
# Processing Record 25 of Set 1 : saint anthony
# Processing Record 26 of Set 1 : chokurdakh
# Processing Record 27 of Set 1 : yeppoon
# Processing Record 28 of Set 1 : iwanai
# Processing Record 29 of Set 1 : hermanus
# Processing Record 30 of Set 1 : punta arenas
# Processing Record 31 of Set 1 : chuy
# Processing Record 32 of Set 1 : mataura
# Processing Record 33 of Set 1 : bredasdorp
# Processing Record 34 of Set 1 : lincoln
# Processing Record 35 of Set 1 : guerrero negro
# Processing Record 36 of Set 1 : lagoa
# Processing Record 37 of Set 1 : portland
# Processing Record 38 of Set 1 : ushuaia
# Processing Record 39 of Set 1 : fortuna
# Processing Record 40 of Set 1 : busselton
# Processing Record 41 of Set 1 : saldanha
# Processing Record 42 of Set 1 : tezu
# Processing Record 43 of Set 1 : te anau
# Processing Record 44 of Set 1 : nikolskoye
# Processing Record 45 of Set 1 : pacific grove
# Processing Record 46 of Set 1 : laguna
# Processing Record 47 of Set 1 : jamestown
# Processing Record 48 of Set 1 : carnarvon
# City not found. Skipping...
# Processing Record 49 of Set 1 : kaitangata
# Processing Record 50 of Set 1 : lufilufi
# Processing Record 0 of Set 2 : russell
# City not found. Skipping...
# Processing Record 1 of Set 2 : saint-philippe
# Processing Record 2 of Set 2 : inhambane
# Processing Record 3 of Set 2 : bluff
# Processing Record 4 of Set 2 : kysyl-syr
# City not found. Skipping...
# Processing Record 5 of Set 2 : puerto ayora
# Processing Record 6 of Set 2 : arraial do cabo
# Processing Record 7 of Set 2 : ribeira grande
# City not found. Skipping...
# Processing Record 8 of Set 2 : houma
# Processing Record 9 of Set 2 : kodiak
# Processing Record 10 of Set 2 : sangar
# Processing Record 11 of Set 2 : lompoc
# Processing Record 12 of Set 2 : broome
# Processing Record 13 of Set 2 : longyearbyen
# Processing Record 14 of Set 2 : maragogi
# Processing Record 15 of Set 2 : coihaique
# Processing Record 16 of Set 2 : aksarka
# Processing Record 17 of Set 2 : tocopilla
# Processing Record 18 of Set 2 : geraldton
# Processing Record 19 of Set 2 : filadelfia
# Processing Record 20 of Set 2 : kathmandu
# Processing Record 21 of Set 2 : caravelas
# Processing Record 22 of Set 2 : daru
# Processing Record 23 of Set 2 : padang
# Processing Record 24 of Set 2 : castro
# Processing Record 25 of Set 2 : lasa
# Processing Record 26 of Set 2 : torbay
# Processing Record 27 of Set 2 : kani
# Processing Record 28 of Set 2 : norman wells
# Processing Record 29 of Set 2 : san quintin
# Processing Record 30 of Set 2 : waingapu
# Processing Record 31 of Set 2 : ahipara
# Processing Record 32 of Set 2 : erzin
# Processing Record 33 of Set 2 : butaritari
# Processing Record 34 of Set 2 : tres lagoas
# Processing Record 35 of Set 2 : shumskiy
# Processing Record 36 of Set 2 : yellowknife
# Processing Record 37 of Set 2 : katsuura
# Processing Record 38 of Set 2 : awbari
# Processing Record 39 of Set 2 : bowen
# Processing Record 40 of Set 2 : mandera
# Processing Record 41 of Set 2 : qixingtai
# Processing Record 42 of Set 2 : preobrazheniye
# Processing Record 43 of Set 2 : hasaki
# Processing Record 44 of Set 2 : ierissos
# Processing Record 45 of Set 2 : kastamonu
# Processing Record 46 of Set 2 : iquique
# Processing Record 47 of Set 2 : thompson
# Processing Record 48 of Set 2 : north battleford
# Processing Record 49 of Set 2 : mar del plata
# Processing Record 50 of Set 2 : altay
# Processing Record 0 of Set 3 : abu kamal
# Processing Record 1 of Set 3 : inverness
# City not found. Skipping...
# Processing Record 2 of Set 3 : kasempa
# City not found. Skipping...
# Processing Record 3 of Set 3 : kapaa
# Processing Record 4 of Set 3 : shetpe
# Processing Record 5 of Set 3 : samarai
# Processing Record 6 of Set 3 : paamiut
# Processing Record 7 of Set 3 : ilulissat
# Processing Record 8 of Set 3 : hualmay
# Processing Record 9 of Set 3 : indiana
# Processing Record 10 of Set 3 : avera
# City not found. Skipping...
# Processing Record 11 of Set 3 : ifakara
# Processing Record 12 of Set 3 : kharp
# Processing Record 13 of Set 3 : east london
# Processing Record 14 of Set 3 : englewood
# Processing Record 15 of Set 3 : naze
# Processing Record 16 of Set 3 : asau
# Processing Record 17 of Set 3 : sitka
# Processing Record 18 of Set 3 : martapura
# City not found. Skipping...
# Processing Record 19 of Set 3 : aksu
# Processing Record 20 of Set 3 : nizhniy baskunchak
# Processing Record 21 of Set 3 : kaeo
# Processing Record 22 of Set 3 : pevek
# Processing Record 23 of Set 3 : beaverlodge
# Processing Record 24 of Set 3 : petropavlovka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 3 : new norfolk
# Processing Record 26 of Set 3 : balykshi
# Processing Record 27 of Set 3 : alyangula
# City not found. Skipping...
# Processing Record 28 of Set 3 : sioux lookout
# Processing Record 29 of Set 3 : saint george
# City not found. Skipping...
# Processing Record 30 of Set 3 : shenjiamen
# City not found. Skipping...
# Processing Record 31 of Set 3 : zarubino
# Processing Record 32 of Set 3 : lumby
# Processing Record 33 of Set 3 : srednebelaya
# Processing Record 34 of Set 3 : georgetown
# Processing Record 35 of Set 3 : upernavik
# Processing Record 36 of Set 3 : cidreira
# Processing Record 37 of Set 3 : turukhansk
# Processing Record 38 of Set 3 : praia da vitoria
# Processing Record 39 of Set 3 : khatanga
# Processing Record 40 of Set 3 : sheltozero
# Processing Record 41 of Set 3 : tautira
# Processing Record 42 of Set 3 : tasiilaq
# Processing Record 43 of Set 3 : ponta do sol
# Processing Record 44 of Set 3 : pangnirtung
# Processing Record 45 of Set 3 : sainte-maxime
# Processing Record 46 of Set 3 : chapais
# Processing Record 47 of Set 3 : olafsvik
# Processing Record 48 of Set 3 : gisborne
# Processing Record 49 of Set 3 : bambous virieux
# Processing Record 50 of Set 3 : grindavik
# Processing Record 0 of Set 4 : berdigestyakh
# Processing Record 1 of Set 4 : isangel
# Processing Record 2 of Set 4 : xining
# Processing Record 3 of Set 4 : bozoum
# Processing Record 4 of Set 4 : bethel
# Processing Record 5 of Set 4 : kavieng
# Processing Record 6 of Set 4 : andenes
# Processing Record 7 of Set 4 : tuatapere
# Processing Record 8 of Set 4 : vestmannaeyjar
# Processing Record 9 of Set 4 : muzhi
# Processing Record 10 of Set 4 : tuktoyaktuk
# Processing Record 11 of Set 4 : kanigoro
# City not found. Skipping...
# Processing Record 12 of Set 4 : wageningen
# Processing Record 13 of Set 4 : barrow
# Processing Record 14 of Set 4 : khilchipur
# Processing Record 15 of Set 4 : novobirilyussy
# Processing Record 16 of Set 4 : kenai
# Processing Record 17 of Set 4 : mahdalynivka
# Processing Record 18 of Set 4 : colatina
# Processing Record 19 of Set 4 : victoria
# Processing Record 20 of Set 4 : meulaboh
# Processing Record 21 of Set 4 : necochea
# Processing Record 22 of Set 4 : erenhot
# Processing Record 23 of Set 4 : arlit
# Processing Record 24 of Set 4 : nome
# Processing Record 25 of Set 4 : tiksi
# City not found. Skipping...
# Processing Record 26 of Set 4 : cape town
# Processing Record 27 of Set 4 : bima
# Processing Record 28 of Set 4 : batticaloa
# Processing Record 29 of Set 4 : yar-sale
# Processing Record 30 of Set 4 : ararangua
# Processing Record 31 of Set 4 : vardo
# Processing Record 32 of Set 4 : port hardy
# Processing Record 33 of Set 4 : komsomolskiy
# Processing Record 34 of Set 4 : coahuayana
# Processing Record 35 of Set 4 : camacha
# Processing Record 36 of Set 4 : tual
# City not found. Skipping...
# Processing Record 37 of Set 4 : baruun-urt
# Processing Record 38 of Set 4 : ancud
# Processing Record 39 of Set 4 : maniitsoq
# Processing Record 40 of Set 4 : tagusao
# Processing Record 41 of Set 4 : cherskiy
# Processing Record 42 of Set 4 : birnin kebbi
# Processing Record 43 of Set 4 : itarema
# Processing Record 44 of Set 4 : srednekolymsk
# City not found. Skipping...
# Processing Record 45 of Set 4 : indianola
# City not found. Skipping...
# Processing Record 46 of Set 4 : horsham
# Processing Record 47 of Set 4 : egvekinot
# Processing Record 48 of Set 4 : yulara
# Processing Record 49 of Set 4 : vostok
# Processing Record 50 of Set 4 : yingcheng
# Processing Record 0 of Set 5 : buraydah
# Processing Record 1 of Set 5 : sao joao da barra
# Processing Record 2 of Set 5 : ponta delgada
# City not found. Skipping...
# Processing Record 3 of Set 5 : kyra
# Processing Record 4 of Set 5 : bairiki
# Processing Record 5 of Set 5 : sabha
# Processing Record 6 of Set 5 : adre
# Processing Record 7 of Set 5 : port elizabeth
# Processing Record 8 of Set 5 : mugango
# Processing Record 9 of Set 5 : khandyga
# Processing Record 10 of Set 5 : batemans bay
# Processing Record 11 of Set 5 : svay rieng
# Processing Record 12 of Set 5 : iquitos
# Processing Record 13 of Set 5 : yerbogachen
# Processing Record 14 of Set 5 : mahebourg
# Processing Record 15 of Set 5 : cap malheureux
# Processing Record 16 of Set 5 : senneterre
# Processing Record 17 of Set 5 : pemangkat
# Processing Record 18 of Set 5 : marabba
# Processing Record 19 of Set 5 : lorengau
# Processing Record 20 of Set 5 : dingle
# Processing Record 21 of Set 5 : bama
# Processing Record 22 of Set 5 : abu samrah
# Processing Record 23 of Set 5 : nuuk
# Processing Record 24 of Set 5 : san vicente
# Processing Record 25 of Set 5 : richards bay
# Processing Record 26 of Set 5 : esperance
# Processing Record 27 of Set 5 : urucara
# Processing Record 28 of Set 5 : ambunti
# Processing Record 29 of Set 5 : balaka
# City not found. Skipping...
# Processing Record 30 of Set 5 : boden
# Processing Record 31 of Set 5 : airai
# Processing Record 32 of Set 5 : santa vitoria do palmar
# Processing Record 33 of Set 5 : lovington
# Processing Record 34 of Set 5 : katangli
# Processing Record 35 of Set 5 : yining
# Processing Record 36 of Set 5 : kathu
# Processing Record 37 of Set 5 : makakilo city
# Processing Record 38 of Set 5 : kralendijk
# City not found. Skipping...
# Processing Record 39 of Set 5 : souillac
# Processing Record 40 of Set 5 : marolambo
# Processing Record 41 of Set 5 : novaya zaimka
# Processing Record 42 of Set 5 : el vigia
# Processing Record 43 of Set 5 : nelson bay
# Processing Record 44 of Set 5 : bathsheba
# Processing Record 45 of Set 5 : destin
# Processing Record 46 of Set 5 : narsaq
# Processing Record 47 of Set 5 : vozhega
# Processing Record 48 of Set 5 : sorong
# Processing Record 49 of Set 5 : marsh harbour
# Processing Record 50 of Set 5 : vanino
# City not found. Skipping...
# Processing Record 0 of Set 6 : pisco
# Processing Record 1 of Set 6 : wilmington
# Processing Record 2 of Set 6 : banda aceh
# Processing Record 3 of Set 6 : korla
# Processing Record 4 of Set 6 : fairbanks
# Processing Record 5 of Set 6 : mlonggo
# Processing Record 6 of Set 6 : copiapo
# Processing Record 7 of Set 6 : san fernando
# Processing Record 8 of Set 6 : sibolga
# Processing Record 9 of Set 6 : celestun
# City not found. Skipping...
# Processing Record 10 of Set 6 : zhigansk
# Processing Record 11 of Set 6 : churapcha
# City not found. Skipping...
# Processing Record 12 of Set 6 : inuvik
# Processing Record 13 of Set 6 : mount gambier
# Processing Record 14 of Set 6 : yanam
# Processing Record 15 of Set 6 : tessalit
# Processing Record 16 of Set 6 : codrington
# Processing Record 17 of Set 6 : grakhovo
# Processing Record 18 of Set 6 : dourados
# Processing Record 19 of Set 6 : taltal
# Processing Record 20 of Set 6 : sao filipe
# Processing Record 21 of Set 6 : hami
# City not found. Skipping...
# Processing Record 22 of Set 6 : scottsbluff
# City not found. Skipping...
# Processing Record 23 of Set 6 : lavrentiya
# Processing Record 24 of Set 6 : kieta
# Processing Record 25 of Set 6 : hirtshals
# Processing Record 26 of Set 6 : kasungu
# City not found. Skipping...
# Processing Record 27 of Set 6 : ozoir-la-ferriere
# Processing Record 28 of Set 6 : callaway
# Processing Record 29 of Set 6 : riyadh
# Processing Record 30 of Set 6 : camopi
# Processing Record 31 of Set 6 : alice springs
# Processing Record 32 of Set 6 : nador
# Processing Record 33 of Set 6 : clyde river
# Processing Record 34 of Set 6 : beniganj
# Processing Record 35 of Set 6 : sinnamary
# Processing Record 36 of Set 6 : fairview
# City not found. Skipping...
# Processing Record 37 of Set 6 : las vegas
# Processing Record 38 of Set 6 : sagua la grande
# Processing Record 39 of Set 6 : hambantota
# Processing Record 40 of Set 6 : pemba
# Processing Record 41 of Set 6 : bosaso
# Processing Record 42 of Set 6 : khandbari
# City not found. Skipping...
# Processing Record 43 of Set 6 : leningradskiy
# Processing Record 44 of Set 6 : sol-iletsk
# Processing Record 45 of Set 6 : peleduy
# Processing Record 46 of Set 6 : lata
# Processing Record 47 of Set 6 : hamilton
# Processing Record 48 of Set 6 : gwadar
# Processing Record 49 of Set 6 : macherla
# Processing Record 50 of Set 6 : quatre cocos
# Processing Record 0 of Set 7 : yongan
# Processing Record 1 of Set 7 : tateyama
# City not found. Skipping...
# Processing Record 2 of Set 7 : banalo
# City not found. Skipping...
# Processing Record 3 of Set 7 : aklavik
# Processing Record 4 of Set 7 : raudeberg
# Processing Record 5 of Set 7 : prainha
# Processing Record 6 of Set 7 : el dovio
# Processing Record 7 of Set 7 : soe
# Processing Record 8 of Set 7 : general pico
# Processing Record 9 of Set 7 : provideniya
# Processing Record 10 of Set 7 : ostrovnoy
# Processing Record 11 of Set 7 : ust-koksa
# Processing Record 12 of Set 7 : bardiyah
# Processing Record 13 of Set 7 : taoudenni
# Processing Record 14 of Set 7 : karratha
# Processing Record 15 of Set 7 : coruripe
# Processing Record 16 of Set 7 : giresun
# Processing Record 17 of Set 7 : silver city
# Processing Record 18 of Set 7 : mahajanga
# City not found. Skipping...
# Processing Record 19 of Set 7 : kailua
# Processing Record 20 of Set 7 : parnarama
# Processing Record 21 of Set 7 : najran
# Processing Record 22 of Set 7 : gerash
# Processing Record 23 of Set 7 : vilhena
# Processing Record 24 of Set 7 : erzurum
# Processing Record 25 of Set 7 : el alto
# Processing Record 26 of Set 7 : aguimes
# Processing Record 27 of Set 7 : la ronge
# Processing Record 28 of Set 7 : gulfport
# Processing Record 29 of Set 7 : kununurra
# Processing Record 30 of Set 7 : treinta y tres
# Processing Record 31 of Set 7 : lanxi
# Processing Record 32 of Set 7 : deputatskiy
# Processing Record 33 of Set 7 : kupang
# Processing Record 34 of Set 7 : eucaliptus
# Processing Record 35 of Set 7 : guangyuan
# Processing Record 36 of Set 7 : namibe
# Processing Record 37 of Set 7 : soyo
# Processing Record 38 of Set 7 : wapakoneta
# Processing Record 39 of Set 7 : lewistown
# Processing Record 40 of Set 7 : amuntai
# Processing Record 41 of Set 7 : elista
# Processing Record 42 of Set 7 : vanimo
# Processing Record 43 of Set 7 : purranque
# Processing Record 44 of Set 7 : road town
# Processing Record 45 of Set 7 : dover
# Processing Record 46 of Set 7 : nemuro
# Processing Record 47 of Set 7 : upington
# Processing Record 48 of Set 7 : jalu
# Processing Record 49 of Set 7 : hrubieszow
# Processing Record 50 of Set 7 : ixtapa
# Processing Record 0 of Set 8 : stolin
# Processing Record 1 of Set 8 : sebezh
# Processing Record 2 of Set 8 : jiangyou
# Processing Record 3 of Set 8 : xichang
# Processing Record 4 of Set 8 : virginia beach
# Processing Record 5 of Set 8 : noyabrsk
# Processing Record 6 of Set 8 : ahuimanu
# City not found. Skipping...
# Processing Record 7 of Set 8 : khash
# Processing Record 8 of Set 8 : shimoda
# Processing Record 9 of Set 8 : aksha
# Processing Record 10 of Set 8 : mosbach
# Processing Record 11 of Set 8 : beringovskiy
# Processing Record 12 of Set 8 : macomb
# City not found. Skipping...
# Processing Record 13 of Set 8 : ojinaga
# Processing Record 14 of Set 8 : la romana
# Processing Record 15 of Set 8 : christchurch
# Processing Record 16 of Set 8 : kruisfontein
# Processing Record 17 of Set 8 : karimganj
# Processing Record 18 of Set 8 : robertsport
# Processing Record 19 of Set 8 : buin
# Processing Record 20 of Set 8 : lebu
# Processing Record 21 of Set 8 : harper
# Processing Record 22 of Set 8 : luanda
# Processing Record 23 of Set 8 : nanortalik
# Processing Record 24 of Set 8 : manyana
# Processing Record 25 of Set 8 : mizdah
# Processing Record 26 of Set 8 : sisimiut
# Processing Record 27 of Set 8 : galle
# Processing Record 28 of Set 8 : price
# Processing Record 29 of Set 8 : aykhal
# Processing Record 30 of Set 8 : muana
# Processing Record 31 of Set 8 : narrabri
# Processing Record 32 of Set 8 : nuevo progreso
# Processing Record 33 of Set 8 : bengkulu
# Processing Record 34 of Set 8 : ballina
# City not found. Skipping...
# Processing Record 35 of Set 8 : mamallapuram
# City not found. Skipping...
# Processing Record 36 of Set 8 : ambanja
# Processing Record 37 of Set 8 : alice
# Processing Record 38 of Set 8 : bonavista
# Processing Record 39 of Set 8 : sur
# Processing Record 40 of Set 8 : san rafael
# Processing Record 41 of Set 8 : lazaro cardenas
# Processing Record 42 of Set 8 : kitwe
# Processing Record 43 of Set 8 : constitucion
# Processing Record 44 of Set 8 : massillon
# Processing Record 45 of Set 8 : bandundu
# Processing Record 46 of Set 8 : casablanca
# Processing Record 47 of Set 8 : palmer
# Processing Record 48 of Set 8 : guanare
# Processing Record 49 of Set 8 : acapulco
# Processing Record 50 of Set 8 : portobelo
# City not found. Skipping...
# Processing Record 0 of Set 9 : bodden town
# Processing Record 1 of Set 9 : oktyabrskoye
# Processing Record 2 of Set 9 : soure
# Processing Record 3 of Set 9 : mount isa
# Processing Record 4 of Set 9 : bubaque
# Processing Record 5 of Set 9 : beidao
# Processing Record 6 of Set 9 : manicaragua
# Processing Record 7 of Set 9 : husavik
# Processing Record 8 of Set 9 : cabo san lucas
# Processing Record 9 of Set 9 : meadow lake
# Processing Record 10 of Set 9 : bac lieu
# Processing Record 11 of Set 9 : blagoyevo
# Processing Record 12 of Set 9 : zhuhai
# Processing Record 13 of Set 9 : touros
# Processing Record 14 of Set 9 : tongliao
# Processing Record 15 of Set 9 : gaspe
# Processing Record 16 of Set 9 : kahului
# Processing Record 17 of Set 9 : rehoboth
# Processing Record 18 of Set 9 : mabaruma
# Processing Record 19 of Set 9 : wagga wagga
# Processing Record 20 of Set 9 : sassandra
# Processing Record 21 of Set 9 : nushki
# Processing Record 22 of Set 9 : iqaluit
# Processing Record 23 of Set 9 : boddam
# Processing Record 24 of Set 9 : goedereede
# City not found. Skipping...
# Processing Record 25 of Set 9 : poum
# Processing Record 26 of Set 9 : kidal
# Processing Record 27 of Set 9 : kamenka
# Processing Record 28 of Set 9 : aswan
# Processing Record 29 of Set 9 : carutapera
# Processing Record 30 of Set 9 : ugoofaaru
# Processing Record 31 of Set 9 : agropoli
# Processing Record 32 of Set 9 : kindia
# Processing Record 33 of Set 9 : maldonado
# Processing Record 34 of Set 9 : bridlington
# Processing Record 35 of Set 9 : pangkalanbuun
# Processing Record 36 of Set 9 : chicama
# Processing Record 37 of Set 9 : itoman
# Processing Record 38 of Set 9 : port lincoln
# Processing Record 39 of Set 9 : angoche
# Processing Record 40 of Set 9 : port shepstone
# Processing Record 41 of Set 9 : puqi
# Processing Record 42 of Set 9 : koslan
# Processing Record 43 of Set 9 : ambilobe
# Processing Record 44 of Set 9 : fort nelson
# Processing Record 45 of Set 9 : rafsanjan
# Processing Record 46 of Set 9 : leon
# Processing Record 47 of Set 9 : isiro
# Processing Record 48 of Set 9 : port hueneme
# Processing Record 49 of Set 9 : bang saphan
# Processing Record 50 of Set 9 : sola
# Processing Record 0 of Set 10 : ingham
# Processing Record 1 of Set 10 : anzoategui
# Processing Record 2 of Set 10 : magistralnyy
# Processing Record 3 of Set 10 : kuloy
# Processing Record 4 of Set 10 : pochutla
# Processing Record 5 of Set 10 : corrente
# Processing Record 6 of Set 10 : sandwick
# City not found. Skipping...
# Processing Record 7 of Set 10 : jumla
# Processing Record 8 of Set 10 : haines junction
# Processing Record 9 of Set 10 : tingi
# Processing Record 10 of Set 10 : saint-augustin
# Processing Record 11 of Set 10 : meiganga
# Processing Record 12 of Set 10 : koroni
# Processing Record 13 of Set 10 : mehamn
# Processing Record 14 of Set 10 : samaipata
# Processing Record 15 of Set 10 : miri
# Processing Record 16 of Set 10 : santa rosa
# Processing Record 17 of Set 10 : tilichiki
# Processing Record 18 of Set 10 : okitipupa
# Processing Record 19 of Set 10 : shuyskoye
# Processing Record 20 of Set 10 : caracuaro
# Processing Record 21 of Set 10 : krasnoselkup
# Processing Record 22 of Set 10 : rocha
# Processing Record 23 of Set 10 : fomboni
# Processing Record 24 of Set 10 : gambo
# City not found. Skipping...
# Processing Record 25 of Set 10 : cockburn town
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 10 : jesus carranza
# Processing Record 27 of Set 10 : douglas
# Processing Record 28 of Set 10 : xuzhou
# Processing Record 29 of Set 10 : taksimo
# Processing Record 30 of Set 10 : kempsey
# Processing Record 31 of Set 10 : noumea
# Processing Record 32 of Set 10 : vila velha
# Processing Record 33 of Set 10 : anamur
# Processing Record 34 of Set 10 : koster
# City not found. Skipping...
# Processing Record 35 of Set 10 : kanakapura
# Processing Record 36 of Set 10 : luderitz
# Processing Record 37 of Set 10 : kulhudhuffushi
# Processing Record 38 of Set 10 : port-gentil
# Processing Record 39 of Set 10 : nioro
# City not found. Skipping...
# Processing Record 40 of Set 10 : kutum
# Processing Record 41 of Set 10 : sao paulo de olivenca
# Processing Record 42 of Set 10 : canico
# Processing Record 43 of Set 10 : de aar
# Processing Record 44 of Set 10 : astara
# Processing Record 45 of Set 10 : san patricio
# Processing Record 46 of Set 10 : talnakh
# Processing Record 47 of Set 10 : la sarre
# Processing Record 48 of Set 10 : port blair
# Processing Record 49 of Set 10 : tirat karmel
# Processing Record 50 of Set 10 : amapa
# Processing Record 0 of Set 11 : lyuban
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of Set 11 : san policarpo
# Processing Record 2 of Set 11 : moundsville
# Processing Record 3 of Set 11 : ternova
# Processing Record 4 of Set 11 : ormara
# Processing Record 5 of Set 11 : mayo
# Processing Record 6 of Set 11 : nanakuli
# Processing Record 7 of Set 11 : kez
# Processing Record 8 of Set 11 : sistranda
# Processing Record 9 of Set 11 : valpacos
# Processing Record 10 of Set 11 : kisangani
# Processing Record 11 of Set 11 : puerto quijarro
# Processing Record 12 of Set 11 : clinton
# Processing Record 13 of Set 11 : sogod
# Processing Record 14 of Set 11 : wagar
# Processing Record 15 of Set 11 : vestmanna
# Processing Record 16 of Set 11 : sarab
# Processing Record 17 of Set 11 : san cristobal
# Processing Record 18 of Set 11 : winslow
# Processing Record 19 of Set 11 : azul
# Processing Record 20 of Set 11 : nouadhibou
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# data frame for analysis
weather_data = pd.DataFrame({"City" : city_name_list,
                "Cloudiness" : cloudiness_list,
                "Country" : country_list,
                "Date" : date_list,
                "Humidity" : humidity_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Wind Speed" : wind_speed_list})

weather_data.count()
# Out:
# City          530
# Cloudiness    530
# Country       530
# Date          530
# Humidity      530
# Lat           530
# Lng           530
# Max Temp      530
# Wind Speed    530
# dtype: int64

# %%
# data check
weather_data
# Out:
#               City  Cloudiness Country        Date  Humidity      Lat  \
# 0           Atuona          20      PF  1619267168        77  -9.8000
# 1          Rikitea         100      PF  1619267085        78 -23.1203
# 2            Union           1      US  1619267106        40  40.6334
# 3       Barvinkove          39      UA  1619267182        45  48.9097
# 4        Hithadhoo          80      MV  1619267179        67  -0.6000
# ..             ...         ...     ...         ...       ...      ...
# 525          Sarab          55      IR  1619267336        17  38.6066
# 526  San Cristobal          40      VE  1619267237        89   7.7669
# 527        Winslow           1      US  1619267337        40  35.0242
# 528           Azul          54      AR  1619267337        98 -36.7770
# 529     Nouadhibou           0      MR  1619267337        60  20.9310
#
#           Lng  Max Temp  Wind Speed
# 0   -139.0333     79.63       17.78
# 1   -134.9692     76.41       10.98
# 2    -74.2663     55.99        3.44
# 3     37.0205     51.66       18.54
# 4     73.0833     83.79        5.17
# ..        ...       ...         ...
# 525   44.9883     79.27        7.09
# 526  -72.2250     78.80        2.30
# 527 -110.6974     50.00       14.97
# 528  -59.8585     57.00        5.99
# 529  -17.0347     75.20       12.66
#
# [530 rows x 9 columns]

# %%
# convert to csv file for analysis
weather_data.to_csv("weather_data.csv")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], facecolor = "orange", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (01/17/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
